# %% [markdown]
# # Run this Notebook to set up your Dataset

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install kagglehub

# %% [markdown]
# ## Import Dependencies

# %%
import os
import kagglehub

# %% [markdown]
# ## Set KaggleCache to be visible in Server

# %%
os.environ['KAGGLEHUB_CACHE'] = './KaggleCache'

# %% [markdown]
# ## Download Dataset

# %%
path = kagglehub.dataset_download("andrewmvd/ocular-disease-recognition-odir5k")

# %% [markdown]
# ## Path for use in other Notebook

# %%
print("\nCopy the following line and attach it in the header of other notebooks:\n\n"+"path = '"+path+"'"+"\n")
# Out:
# Copy the following line and attach it in the header of other notebooks:
#
# path = './KaggleCache/datasets/andrewmvd/ocular-disease-recognition-odir5k/versions/2'
