# %% [markdown]
# # Run this Notebook to set up your Dataset

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install -q kagglehub
# !pip install -q nbstripout && python -m nbstripout --install

# %% [markdown]
# ## Import Dependencies

# %%
import os
import kagglehub

# %% [markdown]
# ## Set KaggleCache to be visible in Server

# %%
os.environ['KAGGLEHUB_CACHE'] = './KaggleCache'

# %% [markdown]
# ## Download Dataset

# %%
path = kagglehub.dataset_download("andrewmvd/ocular-disease-recognition-odir5k")

# %% [markdown]
# ## Copy path variable for other Notebooks

# %%
print("\nCopy the following line and attach it in the variables of other notebooks:\n\n"+"path = '"+path+"'"+"\n")
